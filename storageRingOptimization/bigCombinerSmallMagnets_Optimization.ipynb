# %% [markdown]
# Results show that the optimal solution is likely [0.02756689350866037, 0.14407215117976666], with a cost of -1.424029963695268

# %%
import skopt
from bigCombinerSmallMagnets import *

# %%
sol=compute_Sol(5e-6,50,2000,50,bounds=[(0.0,0.3),(0.25,0.5)])
# Out:
# [(0, 60), (0, 50)]
# starting
# 0
# [6, 46]
# 0
# [36, 39]
# 0
# [12, 28]
# 0
# [36, 4]
# 0
# [53, 23]
# 0
# [22, 37]
# 0
# [25, 41]
# 0
# [5, 34]
# 0
# [54, 31]
# 0
# [7, 4]
# 0
# [18, 24]
# 0
# [2, 9]
# 0
# [13, 38]
# 0
# [50, 7]
# 0
# [48, 40]
# 0
# [26, 23]
# 0
# [23, 24]
# 0
# [11, 7]
# 0
# [10, 4]
# 0
# [20, 30]
# 0
# [31, 37]
# 0
# [12, 38]
# 0
# [33, 17]
# 0
# [9, 4]
# 0
# [21, 32]
# 0
# [2, 34]
# 0
# [29, 5]
# 0
# [55, 30]
# 0
# [45, 20]
# 0
# [20, 5]
# 0
# [16, 38]
# 0
# [58, 49]
# 0
# [45, 13]
# 0
# [8, 16]
# 0
# [40, 30]
# 0
# [20, 40]
# 0
# [3, 27]
# 0
# [16, 22]
# 0
# [53, 16]
# 0
# [42, 34]
# 0
# [10, 30]
# 0
# [24, 24]
# 0
# [7, 46]
# 0
# [13, 35]
# 0
# [7, 1]
# 0
# [54, 11]
# 0
# [37, 6]
# 0
# [6, 9]
# [0.029999999999999995, 0.295] [6, 9] 1.2294150806797748 49.86186904778311
# 1
# [42, 5]
# 1
# [7, 14]
# 1
# [53, 43]
# 1
# [0, 12]
# 1
# [32, 12]
# 1
# [35, 0]
# 1
# [23, 1]
# 1
# [52, 28]
# 1
# [6, 41]
# 1
# [2, 13]
# 1
# [35, 34]
# 1
# [10, 46]
# 1
# [59, 10]
# 1
# ...

# %%
import skopt.plots
skopt.plots.plot_convergence(sol)
# Out:
# <AxesSubplot:title={'center':'Convergence plot'}, xlabel='Number of calls $n$', ylabel='$\\min f(x)$ after $n$ calls'>

# %%
skopt.plots.plot_objective(sol)
# Out:
# array([[<AxesSubplot:xlabel='$X_{0}$', ylabel='Partial dependence'>,
#         <AxesSubplot:>],
#        [<AxesSubplot:xlabel='$X_{0}$', ylabel='$X_{1}$'>,
#         <AxesSubplot:xlabel='$X_{1}$', ylabel='Partial dependence'>]],
#       dtype=object)

# %%
print(sol.fun)
print(sol.x)
# Out:
# -1.424029963695268
# [0.02756689350866037, 0.14407215117976666]

# %%
from OptimizerClass import Optimizer
optimizer=Optimizer(get_Lattice())
lattice=get_Lattice()
lattice.elList[2].forceFact = sol.x[0]
lattice.elList[4].forceFact = sol.x[1]
swarm = optimizer.initialize_Random_Swarm_At_Combiner_Output(3e-3,5e0,100)
swarmNew=optimizer.trace_Swarm_Through_Lattice(swarm, 5e-6, 100*lattice.totalLength/lattice.v0Nominal, parallel=True, fastMode=False)

# %%
revList=[]
for particle in swarmNew.particles:
    revList.append(particle.revolutions)
    lattice.show_Lattice(particleCoords=particle.q)

# %%
particle=swarmNew.particles[np.argmax(np.asarray(revList))]
qoArr=particle.qoArr[:100]
pArr=particle.pArr
plt.plot(qoArr[:,0],qoArr[:,1])
plt.grid()
plt.show()
lattice.show_Lattice(particleCoords=particle.q)

# %%
particle.qArr[0],particle.pArr[0]
# Out:
# (array([-7.01741328e-01,  2.20570828e-02, -7.95847207e-05]),
#  array([-199.48203339,   14.47716408,   -0.33074175]))
