# %% [markdown]
# Results show that the optimal solution is likely [0.14882642533973275, 0.1667523020001467], with a cost of -5.14
#
# A second search, with 50% more points, yielded ([0.08831978959044301, 0.129823239005218], -4.39753338743007). THis search had an error fixed so the results may be slightly different. Objective function looked the same however

# %%
import skopt
from bigCombinerBigMagnets import *

# %%
sol=compute_Sol(5e-6,50,2000,50,bounds=[(0.0,0.25),(0.25,0.5)])
# Out:
# [(0, 50), (0, 50)]
# starting
# 0
# [9, 12]
# [0.045, 0.31] [9, 12] 1.9427534438280953 18.999985728300267
# 1
# [15, 44]
# 1
# [46, 6]
# 1
# [34, 19]
# 1
# [28, 1]
# 1
# [47, 19]
# 1
# [30, 41]
# 1
# [11, 6]
# 1
# [21, 47]
# [0.105, 0.485] [21, 47] 1.6872546374014363 32.999933028711226
# 2
# [12, 25]
# 2
# [6, 15]
# 2
# [37, 47]
# 2
# [48, 47]
# 2
# [19, 36]
# 2
# [49, 32]
# 2
# [31, 24]
# [0.155, 0.37] [31, 24] 4.0603918543190165 49.022437094350394
# 3
# [26, 39]
# [0.13, 0.445] [26, 39] 2.6661322343994014 49.94045970497063
# 4
# [7, 38]
# 4
# [7, 24]
# 4
# [20, 4]
# [0.1, 0.27] [20, 4] 2.210550582115079 38.999928565216216
# 5
# [38, 46]
# 5
# [2, 31]
# 5
# [24, 11]
# 5
# [30, 49]
# 5
# [44, 0]
# 5
# [23, 19]
# 5
# [44, 47]
# 5
# [38, 7]
# 5
# [8, 18]
# 5
# [45, 6]
# 5
# [44, 14]
# 5
# [14, 25]
# 5
# [19, 2]
# 5
# [13, 46]
# 5
# [38, 2]
# 5
# [44, 30]
# 5
# [5, 35]
# 5
# [17, 48]
# 5
# [33, 39]
# 5
# [17, 35]
# 5
# [43, 1]
# 5
# [46, 34]
# 5
# [46, 3]
# 5
# [48, 2]
# 5
# [23, 37]
# ...

# %%
import skopt.plots
skopt.plots.plot_convergence(sol.skoptSol)
# Out:
# <AxesSubplot:title={'center':'Convergence plot'}, xlabel='Number of calls $n$', ylabel='$\\min f(x)$ after $n$ calls'>

# %%
skopt.plots.plot_objective_2D(sol.skoptSol,0,1)
# Out:
# <AxesSubplot:>

# %%
sol.x,sol.fun
# Out:
# ([0.08831978959044301, 0.129823239005218], -4.39753338743007)
