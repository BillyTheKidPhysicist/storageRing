# %% [markdown]
# Results show that the optimal solution is likely [0.14882642533973275, 0.1667523020001467], with a cost of -5.14

# %%
import skopt
from bigCombinerBigMagnets import *

# %%
sol=compute_Sol(5e-6,100.0,2000,100)
# Out:
# starting
# 1 [0.3855914005734511, 0.02539006155148943] 0.9258598796728801 1.9999284958345365
# 2 [0.3354336102553885, 0.19478259063219205] 1.036957363726097 2.0598301892998876
# 3 [0.16525844106527568, 0.4710882969596021] 1.1852871088838906 3.9793045663884143
# 4 [0.26423767510979446, 0.09079541559231095] 1.0096073463356017 1.9999518497590592
# 5 [0.3534666499275328, 0.07812702153030734] 0.9941093050977916 1.9834959139279613
# 6 [0.2917748421860909, 0.15141518729209627] 1.7210015991668044 15.435449233913978
# 7 [0.12810370991297948, 0.22023902970964743] 1.3985320240043708 84.99999393979164
# 8 [0.04039541667813903, 0.462875277244511] 1.015667533649436 2.0037680780762828
# 9 [0.3780302527239668, 0.05295676742082686] 1.0099664053116328 2.060786719007288
# 10 [0.08280144953747054, 0.04275338962005207] 0.9822247041160455 3.0114224224686006
# 11 [0.21326256749237338, 0.4457013392551348] 1.1714104062671615 2.9999123457277084
# ...

# %%
import skopt.plots
skopt.plots.plot_convergence(sol)
# Out:
# <AxesSubplot:title={'center':'Convergence plot'}, xlabel='Number of calls $n$', ylabel='$\\min f(x)$ after $n$ calls'>

# %%
skopt.plots.plot_objective(sol)
# Out:
# array([[<AxesSubplot:xlabel='$X_{0}$', ylabel='Partial dependence'>,
#         <AxesSubplot:>],
#        [<AxesSubplot:xlabel='$X_{0}$', ylabel='$X_{1}$'>,
#         <AxesSubplot:xlabel='$X_{1}$', ylabel='Partial dependence'>]],
#       dtype=object)

# %%
sol.fun
# Out:
# -5.141150513510735
